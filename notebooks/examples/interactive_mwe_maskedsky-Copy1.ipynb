# %% [markdown]
# ![D.lensalot logo](./../../res/dlensalot2.PNG)
#
# # Interactive minimal working example - masked sky
# In this notebook you perfrom QE and iterative lensing reconstruction for a single simulation, and for a masked sky.
# The simulations are created upon runtime inclusive of isotropic white noise and without foregrounds, using a built-in CMB-simulations module.
#
# We generate a simple mask leaving us with a sky fraction of about 17 percent.
# Masked data for iterative lensing reconstruction results in a large, so called mean-field, and biases the lensing potential estimate.
# To remove this bias, you will estimate the mean-field from a set of simulations.
#
# We will use an isotropic noise model and ignore that the data is masked when we deproject the B-modes.
# This is an approximation, and it were better to use the `build_OBD` job to create a better noise model.
# However, this is out of scope for this tutorial.
#
# At the end of this tutorial, you will plot the mean-field subtracted lensing potential estimate and obtain delensed power spectra to calculate the residual lensing amplitude.
#
# The configuration file is [here](https://github.com/NextGenCMB/D.lensalot/blob/sv3.1/lenscarf/ana/config/examples/mwe/conf_mwe_maskedsky.py), and you can freely change the parameters to your liking. In this configuration file, there are a few objects:
#
#  * `DLENSALOT_Analysis` collects all configurations for the analysis of the data/simulations
#  * `DLENSALOT_Data` configures the data which is used. In this minimal working example, we generate the simulation data on the fly and therefore need to choose the simulation module and a few parameters for this
#  * `DLENSALOT_Noisemodel` configures the noise model with which the Wiener-filtering is done.
#  * `DLENSALOT_Qerec` and `DLENSALOT_Itrec` are lensing reconstruction specific settings.

# %%
import os
from os.path import join as opj
import numpy as np
import healpy as hp

import matplotlib.pyplot as plt

import lenscarf
from lenscarf.run import run

from lenscarf.lerepi.visalot import plot_helper as ph

bpl, bpu = (5,200)
def scale_and_bandpass(data):
    return ph.bandpass_alms(hp.almxfl(data,np.sqrt(ll*(ll+1))), bpl, bpu)
# Out:
# cond4mpi does not exists
# could not setup healpix hack. reverting to standard healpy
# MSC: using scarf with 2 OMP threads

# %%
import ducc0

# %% [markdown]
# # Create mask
# Any mask will do as long as the remaining sky fraction is large enough to calculate an unbinned power spectrum of the residual maps later

# %%
m = np.zeros(hp.nside2npix(1))
m[[11,2,7,10]] = 1
rhits = np.abs(hp.smoothing(hp.ud_grade(m, nside_out=1024),0.1))
mask = hp.ud_grade(m, nside_out=1024)
hp.mollview(mask, nest=False, title='mask')
hp.mollview(rhits, nest=False, title='rhits')
print('fsky: {:.3f}'.format(np.mean(m)))

mask_fn = opj(os.environ['SCRATCH'], 'dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky_nside1024/mask.fits')
rhits_fn = opj(os.environ['SCRATCH'], 'dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky_nside1024/rhits.fits')
if not os.path.isdir(os.path.dirname(mask_fn)):
    os.makedirs(os.path.dirname(mask_fn))
if not os.path.isfile(mask_fn):
    hp.write_map(mask_fn, mask)
    hp.write_map(rhits_fn, rhits)
    print('mask and rhits stored at {}'.format(os.path.dirname(mask_fn)))
# Out:
# fsky: 0.333

# %% [markdown]
# # QE lensing reconstruction
# The following cell,
#
#  * line 1: selects the [configuration file](https://github.com/NextGenCMB/D.lensalot/blob/sv3.1/lenscarf/ana/config/examples/mwe/conf_mwe_maskedsky.py) ,
#  * line 2: initialises D.lensalot for a QE lensing reconstruction job (`job_id`),
#  * line 3: perfroms lensing reconstruction and calculates both, the lensing potential, and the B-lensing template.
#
#
# When run for the first time, `.run()` generates CMB simulations and stores them as defined in the `DLENSALOT_data.class_parameters.lib_dir` parameter (check out the configuration file). If this path is not convenient, please choose one that works for you.
#
# This cell will take a while as it also calculates the QE mean-field. This is needed, as the masking of the data induces a strong bias in the low-ell lensing potential.
# For QE, once the mean-field is calculated, it is subtracted from the QE lensing potential estimate to remove this bias.
# This QE estimate is later used as a starting point for iterative lensing reconstruction.
#
# This cell takes ~30min (QE estimates to calculate mean-field) + ~30min (generation of simulation data)

# %%
fn = opj(os.path.dirname(os.path.abspath(lenscarf.__file__)),'ana/config/examples/mwe/conf_mwe_maskedsky.py')
ana_mwe = run(config=fn, job_id='QE_lensrec', verbose=True).job
ana_mwe.run()
# Out:
# INFO:: 02-07 03:19:: lenscarf.lerepi.core.handler.log - load_configfile() Started: /global/u2/s/sebibel/git/lenscarf/lenscarf/ana/config/examples/mwe/conf_mwe_maskedsky.py
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_74051/1779715175.py in <module>
#       1 fn = opj(os.path.dirname(os.path.abspath(lenscarf.__file__)),'ana/config/examples/mwe/conf_mwe_maskedsky.py')
# ----> 2 ana_mwe = run(config=fn, job_id='QE_lensrec', verbose=True).job
#       3 ana_mwe.run()
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/run.py in __init__(self, config, job_id, verbose, madel_kwargs)
#      41         parser.status = ''
#      42
# ---> 43         lerepi_handler = handler.handler(parser, madel_kwargs)
#      44         if job_id == 'interactive':
#      45             ## This is notebook interactive job. (Doesn't appear in config file job list)
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/lerepi/core/handler.py in __init__(self, parser, madel_kwargs)
#      37             parser (_type_): _description_
#      38         """
# ---> 39         self.configfile = handler.load_configfile(parser.config_file, 'configfile')
#      40         # TODO hack. remove when v1 is gone
#      41         if 'madel' in self.configfile.dlensalot_model.__dict__:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/lerepi/core/handler.py in load_configfile(directory, descriptor)
#     185         p = iu.module_from_spec(spec)
#     186         sys.modules[descriptor] = p
# --> 187         spec.loader.exec_module(p)
#     188
#     189         return p
#
# ~/.conda/envs/py3.7p/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/.conda/envs/py3.7p/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/ana/config/examples/mwe/conf_mwe_maskedsky.py in <module>
#      39             'lmax': 2048,
#      40             'cls_unl': utils.camb_clfile(opj(opj(os.path.dirname(plancklens.__file__), 'data', 'cls'), 'FFP10_wdipole_lenspotentialCls.dat')),
# ---> 41             'lib_dir': opj(os.environ['CSCRATCH'], 'generic', 'nside_1024', 'lmax_2048', 'nlevp_sqrt(2)')
#      42         },
#      43         nlev_t = 1.00,
#
# ~/.conda/envs/py3.7p/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'CSCRATCH'

# %% [markdown]
# ## Check QE results
#
# `get_plm` and `get_meanfield_normalized` returns the normalized lensing potential and mean-field.
# Let us plot it to see if they look as expected

# %%
ll = np.arange(0,ana_mwe.qe_lm_max_qlm[0]+1,1)
scale_factor = (ll*(ll+1))**2/(2*np.pi)
mask = hp.read_map(ana_mwe.mask_fn)

mf_QE = ana_mwe.get_meanfield_normalized(0)
plm_QE = ana_mwe.get_plm(0, [0])

# %%
hp.mollview(hp.alm2map(scale_and_bandpass(mf_QE), nside=512), title='mean-field, QE', cmap='YlGnBu')
hp.mollview(hp.alm2map(scale_and_bandpass(plm_QE), nside=512), title='lensing potential estimate, QE', cmap='YlGnBu')
hp.mollview(mask*hp.alm2map(scale_and_bandpass(plm_QE), nside=512), cmap='YlGnBu', title='fiducial lensing potential')

# %%
plt.plot(scale_factor*ana_mwe.cpp, label=r'$C_L^{\phi\phi,{\rm fid}}$')
plt.plot(scale_factor*hp.alm2cl(plm_QE)/np.mean(mask), label=r'$C_L^{\hat{\phi}^{\rm QE}\hat{\phi}^{\rm QE}}$')

plt.plot(scale_factor*hp.alm2cl(mf_QE)/np.mean(mask), label=r'$C_L^{\hat{\phi}^{\rm MF}\hat{\phi}^{\rm MF}}$')

plt.legend(fontsize=18, loc='upper right')
plt.xlabel('Multipole, L', fontsize=14)
plt.ylabel(r'$\left[L(L+1)\right]^2/(2\pi)$', fontsize=14)
plt.xscale('log')
plt.xlim(1,1e3)
plt.ylim(1e-9,1e-6)
plt.yscale('log')

# %% [markdown]
# # iterative lensing reconstruction
#
# The following cell repeats above, but for the iterative case. The settings can be chosen in the configuration file.

# %%
fn = opj(os.path.dirname(os.path.abspath(lenscarf.__file__)),'ana/config/examples/mwe/conf_mwe_maskedsky.py')
ana_mwe = run(config=fn, job_id='MAP_lensrec', verbose=True).job
ana_mwe.run()
# Out:
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - load_configfile() Started: /global/u2/s/sebibel/git/lenscarf/lenscarf/ana/config/examples/mwe/conf_mwe_maskedsky.py
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - load_configfile() Finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - store() Started
# WARNING:: 02-07 02:30:: root.store - config file /global/cscratch1/sd/sebibel/dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky/conf_mwe_maskedsky.py already exist. Checking differences.
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - load_configfile() Started: /global/cscratch1/sd/sebibel/dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky/conf_mwe_maskedsky.py
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - load_configfile() Finished
# INFO:: 02-07 02:30:: root.store - config file look the same. Resuming where I left off last time.
# INFO:: 02-07 02:30:: root.store - Matching config file found. Resuming where I left off.
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - store() Finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - collect_jobs() Started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - collect_jobs() Finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - get_jobs() Started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - get_jobs() Finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - init_job() Started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - transform started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - build() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Meta() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Meta() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Computing() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Computing() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Analysis() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Analysis() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Noisemodel() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Noisemodel() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Data() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Data() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Qerec() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - get_ninvt() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - get_ninvt() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - get_ninvp() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - get_ninvp() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Qerec() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Itrec() started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - _process_Itrec() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.build -
# Configuration:
# ---------------------------------------------------
#
# ---------------------------------------------------
#
# ---------------------------------------------------
# dversion:
# tr:                  	2
# dlm_mod_fnsuffix:
# dlm_mod_bool:        	False
# mask_fn:             	/global/cscratch1/sd/sebibel/dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky/mask.fits
# k:                   	p_p
# version:
# simidxs:             	<class 'numpy.ndarray'>
# simidxs_mf:          	<class 'numpy.ndarray'>
# Nmf:                 	40
# TEMP_suffix:         	my_first_dlensalot_analysis_maskedsky
# TEMP:                	/global/cscratch1/sd/sebibel/dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky
# cls_unl:             	<class 'dict'>
# cls_len:             	<class 'dict'>
# Lmin:                	2
# zbounds:             	(-1, 1)
# zbounds_len:         	(-1, 1)
# pb_ctr:              	0.0
# pb_extent:           	6.283185307179586
# lm_max_ivf:          	(1024, 1024)
# sky_coverage:        	isotropic
# spectrum_type:       	white
# lmin_teb:            	(10, 10, 200)
# OBD:                 	False
# nlev_t:              	1.0
# nlev_p:              	1.4142135623730951
# tpl:                 	None
# _sims:               	<lenscarf.sims.generic.sims_cmb_len object at 0x15551224a090>
# sims:                	<plancklens.sims.maps.cmb_maps_nlev object at 0x15550d5e3250>
# transferfunction:    	gauss_with_pixwin
# ttebl:               	<class 'dict'>
# ftebl_len:           	<class 'dict'>
# ftebl_unl:           	<class 'dict'>
# btemplate_perturbative_lensremap:	True
# qe_tasks:            	<class 'list'>
# QE_subtract_meanfield:	True
# qe_lm_max_qlm:       	(1024, 1024)
# ninvjob_qe_geometry: 	<scarf.Geometry object at 0x155511f801f0>
# cg_tol:              	0.001
# chain_model:         	p0:                  	0
# p1:                  	<class 'list'>
# p2:                  	None
# p3:                  	2048
# p4:                  	inf
# p5:                  	None
# p6:                  	tr_cg
# p7:                  	cache_mem
#
# chain_descr:         	<function l2lensrec_Transformer.build.<locals>._process_Qerec.<locals>.<lambda> at 0x15550d4f3200>
# qe_filter_directional:	anisotropic
# ninvt_desc:          	<class 'list'>
# ninvp_desc:          	<class 'list'>
# cinv_t:              	<plancklens.filt.filt_cinv.cinv_t object at 0x1555125819d0>
# cinv_p:              	<plancklens.filt.filt_cinv.cinv_p object at 0x15551207b610>
# ivfs:                	<plancklens.filt.filt_util.library_ftl object at 0x15550e4a2450>
# qlms_dd:             	<plancklens.qest.library object at 0x155511f75d10>
# cl_analysis:         	False
# it_tasks:            	<class 'list'>
# lm_max_unl:          	(1024, 1024)
# it_lm_max_qlm:       	(1024, 1024)
# it_chain_model:      	p0:                  	0
# p1:                  	<class 'list'>
# p2:                  	None
# p3:                  	512
# p4:                  	inf
# p5:                  	None
# p6:                  	tr_cg
# p7:                  	cache_mem
#
# it_chain_descr:      	<function l2lensrec_Transformer.build.<locals>._process_Itrec.<locals>.<lambda> at 0x15550e4bb680>
# lenjob_geometry:     	<scarf.Geometry object at 0x15550e4b3bf0>
# lenjob_pbgeometry:   	<lenscarf.utils_scarf.pbdGeometry object at 0x15550e4b3110>
# mf_dirname:          	/global/cscratch1/sd/sebibel/dlensalot/lenscarf/generic/sims_cmb_len_lminB200_my_first_dlensalot_analysis_maskedsky/mf_Nmf040
# it_cg_tol:           	<function l2lensrec_Transformer.build.<locals>._process_Itrec.<locals>.<lambda> at 0x15550e4bb4d0>
# it_filter_directional:	anisotropic
# sims_MAP:            	<lenscarf.utils_sims.ztrunc_sims object at 0x15550e4b3150>
# itmax:               	1
# iterator_typ:        	constmf
# lensres:             	1.7
# mfvar:               	None
# soltn_cond:          	<function DLENSALOT_Itrec.<lambda> at 0x15550e5b2d40>
# stepper_model:       	typ:                 	harmonicbump
# lmax_qlm:            	4000
# mmax_qlm:            	4000
# xa:                  	400
# xb:                  	1500
#
# stepper:             	<lenscarf.iterators.steps.nrstep object at 0x155511f6fb90>
# cpp:                 	<class 'numpy.ndarray'>
# ninvjob_geometry:    	<scarf.Geometry object at 0x15550e4b33f0>
# ---------------------------------------------------
# ---------------------------------------------------
# ---------------------------------------------------
#
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.transformer.lerepi2dlensalot.log - build() finished
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - transform done
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - model init started
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - model init done
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - collect_jobs started
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - collect_jobs() started
# INFO:: 02-07 02:30:: lenscarf.core.handler.collect_jobs - Waiting for all ranks to finish their task
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - collect_jobs() finished: jobs=[[0]]
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.init_job - collect_jobs done
# INFO:: 02-07 02:30:: lenscarf.lerepi.core.handler.log - init_job() Finished
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - run() started
# INFO:: 02-07 02:30:: lenscarf.core.handler.run - 0, task calc_blt started
# INFO:: 02-07 02:30:: lenscarf.core.handler.run - 0, task calc_blt started, jobs: [0]
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_wflm(0) started
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_wflm(0) finished
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_meanfield(0) started
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_meanfield(0) finished
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_plm(0) started
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_plm(0) finished
# INFO:: 02-07 02:30:: lenscarf.remapping.__init__ -  Deflection std 0.00e+00 amin
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_datmaps() started
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_datmaps() finished
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_filter() started
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_filter_aniso() started
# INFO:: 02-07 02:30:: lenscarf.opfilt.opfilt_ee_wl.__init__ - *** alm_filter_ninv: switching to same ninv_geometry but with unit weights
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_filter_aniso() finished
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_filter() finished
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_iterator() started
# INFO:: 02-07 02:30:: lenscarf.iterators.iteration_handler.log - get_iterator() finished
# INFO:: 02-07 02:30:: lenscarf.core.handler.log - get_blt_it(0, 1) started
# INFO:: 02-07 02:30:: lenscarf.iterators.cs_iterator.log - get_template_blm(it=1) started
# INFO:: 02-07 02:30:: lenscarf.remapping.__init__ -  Deflection std 2.10e+01 amin
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_33548/2544638861.py in <module>
#       1 fn = opj(os.path.dirname(os.path.abspath(lenscarf.__file__)),'ana/config/examples/mwe/conf_mwe_maskedsky.py')
#       2 ana_mwe = run(config=fn, job_id='MAP_lensrec', verbose=True).job
# ----> 3 ana_mwe.run()
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/core/handler.py in run(self)
#     663                     self.itlib = self.ith(self.qe, self.k, simidx, self.version, self.libdir_iterators, self.dlensalot_model)
#     664                     self.itlib_iterator = self.itlib.get_iterator()
# --> 665                     self.get_blt_it(simidx, self.itmax)
#     666
#     667
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/core/handler.py in get_blt_it(self, simidx, it)
#     727                 dlm_mod = (dlm_mod - np.array(rec.load_plms(self.lib_dir_iterator, [it]))/self.Nmf) * self.Nmf/(self.Nmf - 1)
#     728         if it>0 and it<=rec.maxiterdone(self.lib_dir_iterator):
# --> 729             return self.itlib_iterator.get_template_blm(it, it, lmaxb=1024, lmin_plm=1, dlm_mod=dlm_mod, perturbative=False)
#     730
#     731
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/iterators/cs_iterator.py in get_template_blm(self, it, it_e, lmaxb, lmin_plm, elm_wf, dlm_mod, perturbative)
#     251         else: # Applies full remapping
#     252             ffi = self.filter.ffi.change_dlm([dlm, None], self.mmax_qlm)
# --> 253             elm, blm = ffi.lensgclm([elm_wf, np.zeros_like(elm_wf)], self.mmax_filt, 2, lmaxb, mmaxb)
#     254
#     255         if cache_cond:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in lensgclm(self, gclm, mmax, spin, lmax_out, mmax_out, backwards, nomagn)
#     411             return np.array([glmret, alm_copy(gclm[1], mmax, lmax_out, mmax_out) if gclm[1] is not None else np.zeros_like(glmret)])
#     412         self.tim.reset_t0()
# --> 413         lenm = self.gclm2lenmap(gclm, mmax, spin, backwards, nomagn=nomagn)
#     414         self.tim.add('gclm2lenmap, total')
#     415         if mmax_out is None: mmax_out = lmax_out
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in gclm2lenmap(self, gclm, mmax, spin, backwards, nomagn)
#     380         self.tim.add('glm spin %s lmax %s interpolator setup' % (
#     381         spin, Alm.getlmax((gclm[0] if abs(spin) > 0 else gclm).size, mmax)))
# --> 382         thtn, phin = self._bwd_angles() if backwards else self._fwd_angles()
#     383         self.tim.add('getting angles')
#     384
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in _fwd_angles(self)
#     175                     assert phis.size == pixs.size, (phis.size, pixs.size)
#     176                     thts = self.geom.get_theta(ir) * np.ones(pixs.size)
# --> 177                     thtp_, phip_ = d2ang(red[pixs], imd[pixs], thts , phis, int(np.round(np.cos(self.geom.theta[ir]))))
#     178                     sli = slice(startpix, startpix + len(pixs))
#     179                     thp_phip[0, sli] = thtp_
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/utils_remapping.py in d2ang(red, imd, tht, phi, version, sint_dphi)
#      40     assert version in [1, 0, -1], version
#      41     d = np.sqrt(red ** 2 + imd ** 2)
# ---> 42     assert np.max(d) <= 0.01, (np.max(d), np.max(np.abs(red)), np.max(np.abs(imd)), 'CMB Lensing deflections should never be that big')
#      43
#      44     sind_d = 1. + _sind_d_m1(d)  # sin(d) / d avoiding division by zero or near zero, assuming small deflections
#
# AssertionError: (0.010034001503064148, 0.009951387459023794, 0.004106672848819754, 'CMB Lensing deflections should never be that big')

# %% [markdown]
# # Check your results
# ## lensing potential and mean-field
# After completion of above cells, we can look at the reconstructed lensing potential.
# `get_plm_it(idx, its)` returns the spherical harmonics of the lensing potential estimate for simulation `idx` and iteration `its`

# %%
ll = np.arange(0,ana_mwe.qe_lm_max_qlm[0]+1,1)
scale_factor = (ll*(ll+1))**2/(2*np.pi)
mask = hp.read_map(ana_mwe.mask_fn)

# %%
plm_QE = ana_mwe.get_plm_it(0, [0])[0]
plm_MAP = ana_mwe.get_plm_it(0, [1])[0]

plt.plot(scale_factor*ana_mwe.cpp, label=r'$C_L^{\phi\phi,{\rm fid}}$')
plt.plot(scale_factor*hp.alm2cl(plm_QE)/np.mean(mask), label=r'$C_L^{\hat{\phi}^{\rm QE}\hat{\phi}^{\rm QE}}$')
plt.plot(scale_factor*hp.alm2cl(plm_MAP)/np.mean(mask), label=r'$C_L^{\hat{\phi}^{\rm MAP}\hat{\phi}^{\rm MAP}}$')

plt.legend(fontsize=18, loc='upper right')
plt.xlabel('Multipole, L', fontsize=14)
plt.ylabel(r'$\left[L(L+1)\right]^2/(2\pi)$', fontsize=14)
plt.xscale('log')
plt.xlim(1,1e3)
plt.ylim(1e-9,5e-5)
plt.yscale('log')
# Out:
# INFO:: 02-07 02:05:: lenscarf.core.handler.log - get_plm_it(0, [0]) started
# INFO:: 02-07 02:05:: lenscarf.core.handler.log - get_plm_it(0, [0]) finished
# INFO:: 02-07 02:05:: lenscarf.core.handler.log - get_plm_it(0, [1]) started
# INFO:: 02-07 02:05:: lenscarf.core.handler.log - get_plm_it(0, [1]) finished

# %%
hp.mollview(hp.alm2map(scale_and_bandpass(plm_MAP), nside=2048), cmap='YlGnBu', title='lensing potential estimate, MAP')
hp.mollview(hp.alm2map(scale_and_bandpass(ana_mwe._sims.get_sim_plm(0)), nside=2048), title='fiducial lensing potential', cmap='YlGnBu')
# hp.mollview(hp.alm2map(scale_and_bandpass(plm_MAP-plm_QE), nside=2048), cmap='YlGnBu', title='difference MAP-QE lensing potential estimate')
# hp.mollview(hp.alm2map(scale_and_bandpass(plm_MAP-ana_mwe._sims.get_sim_plm(0)), nside=2048), cmap='YlGnBu', title='difference MAP-fiducial lensing potential estimate')

# %% [markdown]
# # Delensed spectrum
# For both QE and iterative lensing reconstruction, D.lensalot already calculated the B-lensing templates. You can use them to delens the B-lensing maps and obtain residual maps

# %%
input_blensing = hp.map2alm(hp.alm2map(ana_mwe._sims.get_sim_blm(0), nside=2048), lmax=1024)
blt_QE = ana_mwe.get_blt_it(0, 0)
blt_MAP = ana_mwe.get_blt_it(0, 1)
# Out:
# INFO:: 02-07 02:31:: lenscarf.core.handler.log - get_blt_it(0, 0) started
# INFO:: 02-07 02:31:: lenscarf.core.handler.log - get_blt_it(0, 0) finished
# INFO:: 02-07 02:31:: lenscarf.core.handler.log - get_blt_it(0, 1) started
# INFO:: 02-07 02:31:: lenscarf.iterators.cs_iterator.log - get_template_blm(it=1) started
# INFO:: 02-07 02:31:: lenscarf.remapping.__init__ -  Deflection std 2.10e+01 amin
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_33548/1993971508.py in <module>
#       1 input_blensing = hp.map2alm(hp.alm2map(ana_mwe._sims.get_sim_blm(0), nside=2048), lmax=1024)
#       2 blt_QE = ana_mwe.get_blt_it(0, 0)
# ----> 3 blt_MAP = ana_mwe.get_blt_it(0, 1)
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/core/handler.py in get_blt_it(self, simidx, it)
#     727                 dlm_mod = (dlm_mod - np.array(rec.load_plms(self.lib_dir_iterator, [it]))/self.Nmf) * self.Nmf/(self.Nmf - 1)
#     728         if it>0 and it<=rec.maxiterdone(self.lib_dir_iterator):
# --> 729             return self.itlib_iterator.get_template_blm(it, it, lmaxb=1024, lmin_plm=1, dlm_mod=dlm_mod, perturbative=False)
#     730
#     731
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      87     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
#      88         self._do_logging(fn, *args, **kwargs)
# ---> 89         return super().execute(fn, *args, **kwargs)
#      90
#      91
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in wrapper(*args, **kwargs)
#      17         @wraps(fn)
#      18         def wrapper(*args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 19             return self.execute(fn, *args, **kwargs)
#      20
#      21         return wrapper
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#     109
#     110     def execute(self, fn: FunctionType, *args: Any, **kwargs: Any) -> Any:
# --> 111         result = super().execute(fn, *args, **kwargs)
#     112         self._do_logging(fn, result, *args, **kwargs)
#     113
#
# ~/.conda/envs/py3.7p/lib/python3.7/site-packages/logdecorator-2.4-py3.7.egg/logdecorator/decorator.py in execute(self, fn, *args, **kwargs)
#      11
#      12     def execute(self, fn: FunctionType, *args: Tuple[Any], **kwargs: Any) -> Any:
# ---> 13         return fn(*args, **kwargs)
#      14
#      15     def __call__(self, fn: FunctionType) -> Callable[..., Any]:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/iterators/cs_iterator.py in get_template_blm(self, it, it_e, lmaxb, lmin_plm, elm_wf, dlm_mod, perturbative)
#     251         else: # Applies full remapping
#     252             ffi = self.filter.ffi.change_dlm([dlm, None], self.mmax_qlm)
# --> 253             elm, blm = ffi.lensgclm([elm_wf, np.zeros_like(elm_wf)], self.mmax_filt, 2, lmaxb, mmaxb)
#     254
#     255         if cache_cond:
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in lensgclm(self, gclm, mmax, spin, lmax_out, mmax_out, backwards, nomagn)
#     411             return np.array([glmret, alm_copy(gclm[1], mmax, lmax_out, mmax_out) if gclm[1] is not None else np.zeros_like(glmret)])
#     412         self.tim.reset_t0()
# --> 413         lenm = self.gclm2lenmap(gclm, mmax, spin, backwards, nomagn=nomagn)
#     414         self.tim.add('gclm2lenmap, total')
#     415         if mmax_out is None: mmax_out = lmax_out
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in gclm2lenmap(self, gclm, mmax, spin, backwards, nomagn)
#     380         self.tim.add('glm spin %s lmax %s interpolator setup' % (
#     381         spin, Alm.getlmax((gclm[0] if abs(spin) > 0 else gclm).size, mmax)))
# --> 382         thtn, phin = self._bwd_angles() if backwards else self._fwd_angles()
#     383         self.tim.add('getting angles')
#     384
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/remapping.py in _fwd_angles(self)
#     175                     assert phis.size == pixs.size, (phis.size, pixs.size)
#     176                     thts = self.geom.get_theta(ir) * np.ones(pixs.size)
# --> 177                     thtp_, phip_ = d2ang(red[pixs], imd[pixs], thts , phis, int(np.round(np.cos(self.geom.theta[ir]))))
#     178                     sli = slice(startpix, startpix + len(pixs))
#     179                     thp_phip[0, sli] = thtp_
#
# /global/u2/s/sebibel/git/lenscarf/lenscarf/utils_remapping.py in d2ang(red, imd, tht, phi, version, sint_dphi)
#      40     assert version in [1, 0, -1], version
#      41     d = np.sqrt(red ** 2 + imd ** 2)
# ---> 42     assert np.max(d) <= 0.01, (np.max(d), np.max(np.abs(red)), np.max(np.abs(imd)), 'CMB Lensing deflections should never be that big')
#      43
#      44     sind_d = 1. + _sind_d_m1(d)  # sin(d) / d avoiding division by zero or near zero, assuming small deflections
#
# AssertionError: (0.010034001503064148, 0.009951387459023794, 0.004106672848819754, 'CMB Lensing deflections should never be that big')

# %%
blens_residual_QE = input_blensing - blt_QE
blens_residual_MAP = input_blensing - blt_MAP

# %%
plt.plot(hp.alm2cl(input_blensing, lmax=200), label=r'$C_\ell^{BB}$')
plt.plot(hp.alm2cl(blens_residual_QE, lmax=200)/np.mean(mask), label=r'$C_\ell^{BB,{\rm QE,RL}}$')
plt.plot(hp.alm2cl(blens_residual_MAP, lmax=200)/np.mean(mask), label=r'$C_\ell^{BB,{\rm MAP,RL}}$')

plt.legend()
plt.yscale('log')
plt.xlim(0,200)
plt.ylim(1e-7,5e-6)
plt.xlabel('Multipole, $\ell$')
plt.ylabel('$C_\ell [\mu $'+r'$\rm{K}^2$]')

# %% [markdown]
# ## residual lensing amplitude $A_{\rm lens}$
# A simple estimate of the reduction of lensing power is to take the ratio between the input and resdiual B-lensing signal, averaged across the scales of interest. Here, we simply take the scales about the recombination peak

# %%
print(20*'~.')
print('A_{lens}^{QE}:'+'\t{:.3f}'.format(np.mean((hp.alm2cl(blens_residual_QE, lmax=200)/hp.alm2cl(input_blensing, lmax=200))[30:200])))
print('A_{lens}^{MAP}:'+'\t{:.3f}'.format(np.mean((hp.alm2cl(blens_residual_MAP, lmax=200)/hp.alm2cl(input_blensing, lmax=200))[30:200])))
print(20*'~.')

# %% [markdown]
# # Summary and next steps
# This tutorial demonstrated the usage of D.lensalot on a masked sky, and you obtained lensing potential estimates and residual lensing amplitudes from simulation data generated upon runtime.
#
# D.lensalot can also perfrom lensing reconstruction on more challenging settings such as,
#
#  * inhomogeneous noise,
#  * data inclusive of foreground (residuals).
#
# Further, it can calculate reconstruction noise `N0`, and `N1`, and make analytical predictions for the delensed power spectra.
# It also has MPI support.
#
# Please check out the other tutorials, or see the [documentation](link_to_rtd_doc), or [github](https://github.com/NextGenCMB/D.lensalot) for more.
