# %%
from IPython.display import clear_output
from datetime import datetime

import os
from os.path import join as opj
if "SCRATCH" not in os.environ:
    os.environ["SCRATCH"] = "/mnt/c/Users/sebas/OneDrive/SCRATCH"

import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

import delensalot
from delensalot.run import run
from delensalot.lerepi.visalot import plot_helper as ph


fn = opj(os.getcwd(), 'examples/conf_mwe_workbench.py')
ana_mwe_OBD = run(config=fn, job_id='delens', verbose=True)
ana_mwe_OBD.run()
ana_mwe_OBD = ana_mwe_OBD.job
# Out:
# INFO:: 05-18 11:44:: delensalot.config.handler.log - load_configfile() Started: /mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/notebooks/examples/conf_mwe_workbench.py
# INFO:: 05-18 11:44:: delensalot.config.metamodel.dlensalot_mm.__attrs_post_init__ - Setting default, using P_FS_CMBS4:
# 	{'meta': {'version': '0.2'}, 'job': {'jobs': ['generate_sim', 'QE_lensrec', 'MAP_lensrec']}, 'data': {'beam': 1.0, 'nlev_t': 1.0, 'nlev_p': 1.0, 'epsilon': 1e-05, 'nside': 2048, 'class_parameters': {'lmax': 4096, 'cls_unl': {'tt': array([0.00000000e+00, 3.15384486e+03, 1.08426834e+03, ...,
#        9.66229400e-10, 9.65260803e-10, 9.64292720e-10]), 'ee': array([0.00000000e+00, 0.00000000e+00, 3.62414129e-02, ...,
#        2.00006407e-12, 1.99423451e-12, 1.98828000e-12]), 'bb': array([0., 0., 0., ..., 0., 0., 0.]), 'te': array([0.00000000e+00, 0.00000000e+00, 2.93875049e+00, ...,
#        1.40842175e-11, 1.40724986e-11, 1.40607859e-11]), 'pp': array([0.00000000e+00, 5.94954817e-08, 8.92404300e-09, ...,
#        7.91637420e-25, 7.91001884e-25, 7.90366882e-25]), 'pt': array([0.00000000e+00, 6.20759604e-03, 1.28926184e-03, ...,
#        2.46796544e-19, 2.46782393e-19, 2.46768224e-19]), 'pe': array([ 0.00000000e+00,  0.00000000e+00, -5.60260517e-06, ...,
#         2.53157091e-22,  2.53085247e-22,  2.53013434e-22])}, 'lib_dir': '/mnt/c/Users/sebas/OneDrive/SCRATCH/sims/generic/nside2048/lmax4096/nlevp_sqrt(2)'}, 'lmax_transf': 4500, 'transferfunction': 'gauss_no_pixwin', 'package_': 'delensalot', 'module_': 'sims.generic', 'class_': 'sims_cmb_len'}, 'analysis': {'key': 'p_p', 'version': 'noMF', 'simidxs': array([0]), 'TEMP_suffix': 'P_FS_CMBS4', 'Lmin': 1, 'lm_max_ivf': (4000, 4000), 'lmin_teb': (2, 2, 200), 'simidxs_mf': [], 'zbounds': (-1, 1), 'zbounds_len': (-1, 1), 'pbounds': (0.0, 6.283185307179586), 'lm_max_len': (4000, 4000), 'mask': None, 'cls_unl': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lenspotentialCls.dat', 'cls_len': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lensedCls.dat', 'cpp': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lenspotentialCls.dat', 'beam': 1.0}, 'qerec': {'tasks': ['calc_phi'], 'qlm_type': 'sepTP', 'cg_tol': 0.0001, 'filter_directional': 'isotropic', 'ninvjob_qe_geometry': 'healpix_geometry_qe', 'lm_max_qlm': (4000, 4000), 'cl_analysis': False, 'blt_pert': True, 'chain': {'p0': 0, 'p1': ['diag_cl'], 'p2': None, 'p3': 2048, 'p4': inf, 'p5': None, 'p6': 'tr_cg', 'p7': 'cache_mem'}}, 'itrec': {'stepper': {'typ': 'harmonicbump', 'lmax_qlm': 4000, 'mmax_qlm': 4000, 'a': 0.5, 'b': 0.499, 'xa': 400, 'xb': 1500}, 'chain': {'p0': 0, 'p1': ['diag_cl'], 'p2': None, 'p3': 2048, 'p4': inf, 'p5': None, 'p6': 'tr_cg', 'p7': 'cache_mem'}, 'tasks': ['calc_phi'], 'itmax': 1, 'cg_tol': 1e-05, 'iterator_typ': 'constmf', 'filter_directional': 'isotropic', 'lenjob_geometry': 'thin_gauss', 'lenjob_pbgeometry': 'pbdGeometry', 'lm_max_unl': (4500, 4500), 'lm_max_qlm': (4000, 4000), 'mfvar': '', 'soltn_cond': <function <lambda> at 0x7f24528216c0>}, 'noisemodel': {'sky_coverage': 'isotropic', 'spectrum_type': 'white', 'OBD': False, 'nlev_t': 1.0, 'nlev_p': 1.0, 'rhits_normalised': None, 'ninvjob_geometry': 'healpix_geometry'}, 'madel': {'data_from_CFS': False, 'edges': array([   2,   30,   60,   90,  120,  150,  180,  200,  300,  500,  700,
#        1000, 1500, 2000, 3000, 4000, 5000]), 'nlevels': [inf], 'dlm_mod': False, 'iterations': [5], 'masks_fn': None, 'lmax': 1024, 'lmax_mask': 5000, 'Cl_fid': 'ffp10', 'libdir_it': None, 'binning': 'binned', 'spectrum_calculator': <module 'MSC.pospace' from '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/MSC/MSC/pospace.py'>}, 'computing': {'OMP_NUM_THREADS': 2}, 'obd': {'libdir': -123456789, 'rescale': 1, 'tpl': 'template_dense', 'nlev_dep': 10000.0, 'nside': 2048, 'lmax': 200, 'beam': 1.0}, 'config': {'outdir_plot_root': '/home/belkner/plots', 'outdir_plot_rel': ''}}
# INFO:: 05-18 11:44:: delensalot.config.handler.log - load_configfile() Finished
# INFO:: 05-18 11:44:: delensalot.config.handler.log - store() Started
# WARNING:: 05-18 11:44:: root.store - config file /mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_OBD_workbench/conf_mwe_workbench.py already exist. Checking differences.
# INFO:: 05-18 11:44:: delensalot.config.handler.log - load_configfile() Started: /mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_OBD_workbench/conf_mwe_workbench.py
# INFO:: 05-18 11:44:: delensalot.config.metamodel.dlensalot_mm.__attrs_post_init__ - Setting default, using P_FS_CMBS4:
# 	{'meta': {'version': '0.2'}, 'job': {'jobs': ['generate_sim', 'QE_lensrec', 'MAP_lensrec']}, 'data': {'beam': 1.0, 'nlev_t': 1.0, 'nlev_p': 1.0, 'epsilon': 1e-05, 'nside': 2048, 'class_parameters': {'lmax': 4096, 'cls_unl': {'tt': array([0.00000000e+00, 3.15384486e+03, 1.08426834e+03, ...,
#        9.66229400e-10, 9.65260803e-10, 9.64292720e-10]), 'ee': array([0.00000000e+00, 0.00000000e+00, 3.62414129e-02, ...,
#        2.00006407e-12, 1.99423451e-12, 1.98828000e-12]), 'bb': array([0., 0., 0., ..., 0., 0., 0.]), 'te': array([0.00000000e+00, 0.00000000e+00, 2.93875049e+00, ...,
#        1.40842175e-11, 1.40724986e-11, 1.40607859e-11]), 'pp': array([0.00000000e+00, 5.94954817e-08, 8.92404300e-09, ...,
#        7.91637420e-25, 7.91001884e-25, 7.90366882e-25]), 'pt': array([0.00000000e+00, 6.20759604e-03, 1.28926184e-03, ...,
#        2.46796544e-19, 2.46782393e-19, 2.46768224e-19]), 'pe': array([ 0.00000000e+00,  0.00000000e+00, -5.60260517e-06, ...,
#         2.53157091e-22,  2.53085247e-22,  2.53013434e-22])}, 'lib_dir': '/mnt/c/Users/sebas/OneDrive/SCRATCH/sims/generic/nside2048/lmax4096/nlevp_sqrt(2)'}, 'lmax_transf': 4500, 'transferfunction': 'gauss_no_pixwin', 'package_': 'delensalot', 'module_': 'sims.generic', 'class_': 'sims_cmb_len'}, 'analysis': {'key': 'p_p', 'version': 'noMF', 'simidxs': array([0]), 'TEMP_suffix': 'P_FS_CMBS4', 'Lmin': 1, 'lm_max_ivf': (4000, 4000), 'lmin_teb': (2, 2, 200), 'simidxs_mf': [], 'zbounds': (-1, 1), 'zbounds_len': (-1, 1), 'pbounds': (0.0, 6.283185307179586), 'lm_max_len': (4000, 4000), 'mask': None, 'cls_unl': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lenspotentialCls.dat', 'cls_len': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lensedCls.dat', 'cpp': '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/delensalot/delensalot/data/cls/FFP10_wdipole_lenspotentialCls.dat', 'beam': 1.0}, 'qerec': {'tasks': ['calc_phi'], 'qlm_type': 'sepTP', 'cg_tol': 0.0001, 'filter_directional': 'isotropic', 'ninvjob_qe_geometry': 'healpix_geometry_qe', 'lm_max_qlm': (4000, 4000), 'cl_analysis': False, 'blt_pert': True, 'chain': {'p0': 0, 'p1': ['diag_cl'], 'p2': None, 'p3': 2048, 'p4': inf, 'p5': None, 'p6': 'tr_cg', 'p7': 'cache_mem'}}, 'itrec': {'stepper': {'typ': 'harmonicbump', 'lmax_qlm': 4000, 'mmax_qlm': 4000, 'a': 0.5, 'b': 0.499, 'xa': 400, 'xb': 1500}, 'chain': {'p0': 0, 'p1': ['diag_cl'], 'p2': None, 'p3': 2048, 'p4': inf, 'p5': None, 'p6': 'tr_cg', 'p7': 'cache_mem'}, 'tasks': ['calc_phi'], 'itmax': 1, 'cg_tol': 1e-05, 'iterator_typ': 'constmf', 'filter_directional': 'isotropic', 'lenjob_geometry': 'thin_gauss', 'lenjob_pbgeometry': 'pbdGeometry', 'lm_max_unl': (4500, 4500), 'lm_max_qlm': (4000, 4000), 'mfvar': '', 'soltn_cond': <function <lambda> at 0x7f24528216c0>}, 'noisemodel': {'sky_coverage': 'isotropic', 'spectrum_type': 'white', 'OBD': False, 'nlev_t': 1.0, 'nlev_p': 1.0, 'rhits_normalised': None, 'ninvjob_geometry': 'healpix_geometry'}, 'madel': {'data_from_CFS': False, 'edges': array([   2,   30,   60,   90,  120,  150,  180,  200,  300,  500,  700,
#        1000, 1500, 2000, 3000, 4000, 5000]), 'nlevels': [inf], 'dlm_mod': False, 'iterations': [5], 'masks_fn': None, 'lmax': 1024, 'lmax_mask': 5000, 'Cl_fid': 'ffp10', 'libdir_it': None, 'binning': 'binned', 'spectrum_calculator': <module 'MSC.pospace' from '/mnt/c/Users/sebas/OneDrive/Desktop/Uni/ext/git/MSC/MSC/pospace.py'>}, 'computing': {'OMP_NUM_THREADS': 2}, 'obd': {'libdir': -123456789, 'rescale': 1, 'tpl': 'template_dense', 'nlev_dep': 10000.0, 'nside': 2048, 'lmax': 200, 'beam': 1.0}, 'config': {'outdir_plot_root': '/home/belkner/plots', 'outdir_plot_rel': ''}}
# INFO:: 05-18 11:44:: delensalot.config.handler.log - load_configfile() Finished
# INFO:: 05-18 11:44:: root.store - config file comparison done. No conflicts found.
# INFO:: 05-18 11:44:: root.store - Matching config file found. Resuming where I left off.
# INFO:: 05-18 11:44:: delensalot.config.handler.log - store() Finished
# INFO:: 05-18 11:44:: delensalot.config.handler.log - build_model() Started
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot.log - build() started
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot._process_Computing - OMP_NUM_THREADS: 4 and 4
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot._process_Config - Plots will be stored at /home/belkner/plots/
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot.log - build() finished
# INFO:: 05-18 11:44:: delensalot.config.handler.log - build_model() Finished
# INFO:: 05-18 11:44:: delensalot.config.handler.log - init_job() Started
# INFO:: 05-18 11:44:: delensalot.core.mpi.inner_function - rank: 0, size: 1, name: x86_64 with 12 cpus
# INFO:: 05-18 11:44:: delensalot.config.handler.log - init_job() Finished
# INFO:: 05-18 11:44:: delensalot.core.mpi.inner_function - rank: 0, size: 1, name: x86_64 with 12 cpus
# INFO:: 05-18 11:44:: delensalot.config.handler.log - run() Started
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot.log - build() started
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot._process_Computing - OMP_NUM_THREADS: 4 and 4
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot._process_Config - Plots will be stored at /home/belkner/plots/
# INFO:: 05-18 11:44:: delensalot.config.transformer.lerepi2dlensalot.log - build() finished
# INFO:: 05-18 11:44:: delensalot.core.mpi.inner_function - rank: 0, size: 1, name: x86_64 with 12 cpus
# cond4mpi does not exists. No MPI loaded
# INFO:: 05-18 11:44:: delensalot.core.mpi.inner_function - rank: 0, size: 1, name: x86_64 with 12 cpus
# INFO:: 05-18 11:44:: delensalot.core.handler.log - collect_jobs() started
# INFO:: 05-18 11:44:: delensalot.core.handler.log - collect_jobs() finished: jobs=[0]
# INFO:: 05-18 11:44:: delensalot.core.handler.log - run() started
# INFO:: 05-18 11:44:: delensalot.core.handler.log - _prepare_job() started
# Calculating coupling matrix...
#
# WARNING: map analysis requested with lmax>4*nside...
# is this really what you want?
#
#  [00:00:00]  ---------> 93%
# INFO:: 05-18 11:45:: delensalot.core.handler.log - _prepare_job() finished
# INFO:: 05-18 11:45:: delensalot.core.handler.run - will store file at: /mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_OBD_workbench/plotdata/noMF/b294/ClBB_sim0000.npy
# INFO:: 05-18 11:45:: delensalot.core.handler.log - _delens() started
# INFO:: 05-18 11:45:: delensalot.core.handler._delens - starting mask 0
# INFO:: 05-18 11:45:: delensalot.core.handler._delens - starting MAP delensing for iteration 0
# INFO:: 05-18 11:45:: delensalot.core.handler.log - _delens() finished
# INFO:: 05-18 11:45:: delensalot.core.handler.log - run() finished
# INFO:: 05-18 11:45:: delensalot.config.handler.log - run() Finished

# %%
cls, _ = ana_mwe_OBD.read_data()
# Out:
# INFO:: 05-18 11:46:: delensalot.core.handler.log - read_data() started
# Loading 1 sims
# INFO:: 05-18 11:46:: delensalot.core.handler.log - read_data() finished

# %%
print(ana_mwe_OBD.edges_center)
plt.plot(ana_mwe_OBD.edges_center, cls[0,0,0,:]*ana_mwe_OBD.ct[1:])
plt.plot(ana_mwe_OBD.edges_center, cls[1,0,0,:]*ana_mwe_OBD.ct[1:])
plt.plot(ana_mwe_OBD.edges_center, cls[2,0,0,:]*ana_mwe_OBD.ct[1:])
plt.loglog()
# Out:
# [  16.   45.   75.  105.  135.  165.  190.  250.  400.  600.  850. 1250.
#  1750. 2500. 3500. 4500.]
# []

# %%
ana_mwe_OBD.ct
# Out:
# array([1.97459570e-06, 1.99825561e-06, 2.03276495e-06, 2.04867131e-06,
#        2.07258570e-06, 2.12693451e-06, 2.20625046e-06, 2.25882075e-06,
#        2.20043690e-06, 1.59447428e-06, 1.09974309e-06, 6.26830903e-07,
#        2.40033586e-07, 8.70791079e-08, 1.54773076e-08, 4.34020330e-09,
#        1.72406283e-09])

# %%
fn = opj(os.getcwd(), 'examples/conf_mwe_workbench.py')
ana_mwe_OBD = run(config=fn, job_id='QE_lensrec', verbose=True)
ana_mwe_OBD.run()
ana_mwe_OBD = ana_mwe_OBD.job

clear_output(wait=True)
print("Cell finished {}".format(datetime.now().strftime("%H:%M:%S")))
# Out:
# Cell finished 11:40:17

# %%
fn = opj(os.getcwd(), 'examples/conf_mwe_workbench.py')
ana_mwe_OBD = run(config=fn, job_id='delens', verbose=True)
ana_mwe_OBD.run()
ana_mwe_OBD = ana_mwe_OBD.job
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fn = opj(os.getcwd(), 'examples/conf_mwe_workbench.py')
#       2 ana_mwe_OBD = run(config=fn, job_id='delens', verbose=True)
#       3 ana_mwe_OBD.run()
#
# NameError: name 'opj' is not defined

# %% [markdown]
# # CG solver testing

# %%
its = np.arange(0,27)
residuals_qe_south_mask = [np.load('/mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_lminB200_mfda_maskedsky_south/cgsolver/residual_{}_qe.npy'.format(it)) for it in its]

# %%
for it in np.arange(1,27,4):
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals_qe_south_mask[it]/residuals_qe_south_mask[0]),nside=256)), lonra=[80,190], latra=[-90,0])
    print(it)
    plt.show()
# Out:
# /tmp/ipykernel_12870/3436642894.py:2: RuntimeWarning: invalid value encountered in divide
#   hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals_qe_south_mask[it]/residuals_qe_south_mask[0]),nside=256)), lonra=[80,190], latra=[-90,0])
# 1
# 5
# 9
# 13
# 17
# 21
# 25

# %%
for it in np.arange(1,27,4):
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals_qe_south_mask[it]),nside=256)), lonra=[80,190], latra=[-90,0])
    print(it)
    plt.show()
# Out:
# 1
# 5
# 9
# 13
# 17
# 21
# 25

# %%
its = [1,2]
incrs = [np.load('/mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_lminB200_mfda_maskedsky/p_p_sim0000noMF/increment_it{}.npy'.format(it)) for it in its]

# %%
hp.mollview(hp.alm2map(incrs[0], nside=512))
hp.mollview(hp.alm2map(incrs[1], nside=512))

# %%
plt.plot(hp.alm2cl(incrs[0]))
plt.plot(hp.alm2cl(incrs[1]))
plt.loglog()
plt.xlim(10,4000)
# Out:
# (10, 4000)

# %%
its = np.arange(5)
residuals_it1 = [np.load('/mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_lminB200_mfda_maskedsky/p_p_sim0000noMF/cgsolver/residual_{}_it2.npy'.format(it)) for it in its]

# %%
its = np.arange(8)
residuals_center_it1 = [np.load('/mnt/c/Users/sebas/OneDrive/SCRATCH/delensalot/generic/sims_cmb_len_lminB200_mfda_maskedsky_center/cgsolver/residual_{}_it1.npy'.format(it), allow_pickle=True) for it in its]

# %%
for it in its: # [10,15,19,21]:
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals_center_it1[it]),nside=256)), lonra=[210,330], latra=[-45,45])
    if it>0:
        hp.cartview(np.abs(hp.alm2map(np.nan_to_num((residuals_center_it1[it]/residuals_center_it1[0])),nside=256)), lonra=[210,330], latra=[-45,45])
    print('----')
    plt.show()

# %%
for it in its: # [10,15,19,21]:
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals[it]),nside=512)), lonra=[80,190], latra=[-90,0])
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num(residuals_it1[it]),nside=512)), lonra=[80,190], latra=[-90,0])
    hp.cartview(np.abs(hp.alm2map(np.nan_to_num((residuals_it1[it]/residuals_it1[0])),nside=512)), lonra=[80,190], latra=[-90,0])
    print('----')
    plt.show()
